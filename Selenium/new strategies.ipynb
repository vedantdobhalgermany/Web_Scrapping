# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support import expected_conditions as EC
import time

driver = webdriver.Chrome()
driver.maximize_window()

url = "https://www.w3schools.com/html/tryit.asp?filename=tryhtml_iframe_target"
driver.get(url)
time.sleep(2)

wait = WebDriverWait(driver, 10)


iframe_element = wait.until(EC.frame_to_be_available_and_switch_to_it((By.XPATH, '//*[@id="fast-cmp-iframe"]')))

decline_button = wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="fast-cmp-form"]/span/button')))
decline_button.click()

driver.switch_to.default_content()

iframe_element2 = wait.until(EC.frame_to_be_available_and_switch_to_it((By.XPATH, '//*[@id="iframeResult"]')))

link = driver.find_element(By.XPATH,'/html/body/p[1]/a')
link.click()
time.sleep(2)


driver.switch_to.default_content()

time.sleep(5)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[53], line 29
#      26 iframe_element2 = wait.until(EC.frame_to_be_available_and_switch_to_it((By.XPATH, '//*[@id="iframeResult"]')))
#      28 link = driver.find_element(By.XPATH,'/html/body/p[1]/a')
# ---> 29 link.click()
#      30 time.sleep(2)
#      33 driver.switch_to.default_content()
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)    117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=147.0.7727.57); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementnotinteractableexception
# Stacktrace:
# 0   chromedriver                        0x000000010484fabc cxxbridge1$str$ptr + 3192864
# 1   chromedriver                        0x0000000104847a8c cxxbridge1$str$ptr + 3160048
# 2   chromedriver                        0x00000001043135c4 _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74840
# 3   chromedriver                        0x000000010435c4b0 _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 373572
# 4   chromedriver                        0x00000001043528dc _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 333680
# 5   chromedriver                        0x0000000104352358 _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 332268
# 6   chromedriver                        0x000000010439b448 _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 631516
# 7   chromedriver                        0x0000000104350e50 _RNvCs10ygTOo3JCa_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 326884
# 8   chromedriver                        0x000000010480d248 cxxbridge1$str$ptr + 2920364
# 9   chromedriver                        0x0000000104810a28 cxxbridge1$str$ptr + 2934668
# 10  chromedriver                        0x00000001047f31fc cxxbridge1$str$ptr + 2813792
# 11  chromedriver                        0x00000001048112a8 cxxbridge1$str$ptr + 2936844
# 12  chromedriver                        0x00000001047e4024 cxxbridge1$str$ptr + 2751880
# 13  chromedriver                        0x0000000104836988 cxxbridge1$str$ptr + 3090156
# 14  chromedriver                        0x0000000104836b04 cxxbridge1$str$ptr + 3090536
# 15  chromedriver                        0x00000001048476e4 cxxbridge1$str$ptr + 3159112
# 16  libsystem_pthread.dylib             0x00000001903a3c58 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x000000019039ec1c thread_start + 8
