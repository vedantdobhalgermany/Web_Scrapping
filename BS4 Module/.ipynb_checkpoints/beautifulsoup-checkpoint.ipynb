# %% [markdown]
# # 1. Imports

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # 2. Create a `soup` object

# %%
with open("html-doc.html") as file:
    soup = BeautifulSoup(file, "lxml")

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# # 3. Basics of the `soup` object
#
# - `prettify()`
# - individual tags:
#     - `title`
#     - `a`
#     - `p`
# - `text`
# - `name`
# - `parent`
# - `children`
# - `descendants`
# - `get_text()`
# - `find()`
# - `find_all()`
# - `get()` / square bracket notation

# %%
# prettify 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
# Title tag

print(soup.title)
# Out:
# <title>The Dormouse's story</title>

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# text

soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
type(soup.title)
# Out:
# bs4.element.Tag

# %%
soup.title.text
# Out:
# "The Dormouse's story"

# %%
type(soup.title.text)
# Out:
# str

# %%
soup.title.text.upper()
# Out:
# "THE DORMOUSE'S STORY"

# %%
soup.title.text.lower()
# Out:
# "the dormouse's story"

# %%
soup.title.text.split()
# Out:
# ['The', "Dormouse's", 'story']

# %%
# name 

soup.title.name
# Out:
# 'title'

# %%
# parent -> one above the tag (entirely enclosed the tag)

soup.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.title.parent.parent
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p></body></html>

# %%
# children 

soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p></body>

# %%
soup.body.children
# Out:
# <generator object Tag.children.<locals>.<genexpr> at 0x106b2d2f0>

# %%
for child in soup.body.children:
    print(child)
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
#
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
#
# <p class="story">...</p>

# %%
for child in soup.head.children:
    print(child)
# Out:
# <title>The Dormouse's story</title>

# %%
# descendants

soup.body.descendants
# Out:
# <generator object Tag.descendants at 0x151c73840>

# %%
for desc in soup.body.descendants:
    print(desc)
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# <b>The Dormouse's story</b>
# The Dormouse's story
#
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# Once upon a time there were three little sisters; and their names were
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# Elsie
# ,
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# Lacie
#  and
#
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Tillie
# ;
# and they lived at the bottom of a well.
#
#
# <p class="story">...</p>
# ...

# %%
# get_text()

soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p></body>

# %%
soup.body.get_text()
# Out:
# "\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n..."

# %%
print(soup.body.get_text().strip())
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
type(soup.body.get_text())
# Out:
# str

# %%
print(soup.title.get_text())
# Out:
# The Dormouse's story

# %%
# find()

soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
# find_all()

soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
type(soup.find_all('a'))
# Out:
# bs4.element.ResultSet

# %%
# get()

soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.a['id']
# Out:
# 'link1'

# %%
soup.a.get('class')
# Out:
# ['sister']

# %%
soup.a.get('href')
# Out:
# 'http://example.com/elsie'

# %%
soup.a.get('id')
# Out:
# 'link1'

# %% [markdown]
# # 4. Fetching webpage with `Requests`
#
# - URL: `https://www.bbc.com/sport/football/premier-league/top-scorers`

# %%
url = 'https://www.bbc.com/sport/football/premier-league/top-scorers'

# %%
# GET request

response = requests.get(url)

# %%
# check for errors

response.raise_for_status()

# %%
print(response.raise_for_status())
# Out:
# None

# %%
# status code

response.status_code
# Out:
# 200

# %%
# text (str format)

response.text[:200]
# Out:
# '<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Premier League Top Scorers - B'

# %%
response.content[:200]
# Out:
# b'<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Premier League Top Scorers - B'

# %%
type(response.content[:200])
# Out:
# bytes

# %% [markdown]
# - can use either `content` or `text` attribute to create the soup object
# - with `text`, we must be certain about the encoding
# - with `content`, we let Beautiful Soup handle the encoding mostly

# %%
soup = BeautifulSoup(response.content,"lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-GB">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title data-rh="true">
#    Premier League Top Scorers - BBC Sport
#   </title>
#   <meta content="Premier League top scorers. Showing assists, time on pitch and the shots on and off target." data-rh="true" name="description"/>
#   <meta content="#FFFFFF" data-rh="true" name="theme-color"/>
#   <meta content="light" data-rh="true" name="color-scheme"/>
#   <meta content="Premier League top scorers. Showing assists, time on pitch and the shots on and off target." data-rh="true" property="og:description"/>
#   <meta content="https://static.files.bbci.co.uk/core/website/assets/static/sport/bbc-sport-logo.ebbfcde41a.webp" data-rh="true" property="og:image"/>
#   <meta content="BBC Sport" data-rh="true" property="og:site_name"/>
#   <meta content="Premier League Top Scorers - BBC Sport" data-rh="true" property="og:title"/>
#   <meta content="article" data-rh="true" property="og:type"/>
#   <meta content="https://www.bbc.co.uk/sport/football/premier-league/top-scorers" data-rh="true" property="og:url"/>
#   <meta content="summary" data-rh="true" name="twitter:card"/>
#   <meta content="@BBCSport" data-rh="true" name="twitter:creator"/>
#   <meta content="@BBCSport" data-rh="true" name="twitter:site"/>
#   <meta content="Premier League Top Scorers - BBC Sport" data-rh="true" name="twitter:title"/>
#   <meta content="Premier League top scorers. Showing assists, time on pitch and the shots on and off target." data-rh="true" name="twitter:description"/>
#   <meta content="https://www.bbc.co.uk/sport/football/premier-league/top-scorers" data-rh="true" name="twitter:url"/>
#   <meta content="https://static.files.bbci.co.uk/core/website/assets/static/icons/windows-phone/sport/windows-phone-icon-270x270.3e5b0f9ac9.png" data-rh="true" name="msapplication-TileImage" type="metaTags"/>
#   <meta content="telephone=no" data-rh="true" name="format-detection"/>
#   <meta content="max-image-preview:large" data-rh="true" name="robots"/>
#   <link data-rh="true" href="https://www.bbc.co.uk/sport/football/premier-league/top-scorers" rel="canonical"/>
#   <link data-rh="true" href="https://www.bbc.co.uk/sport/football/premier-league/top-scorers" hreflang="en-gb" rel="alternate"/>
#   <link data-rh="true" href="https://www.bbc.com/sport/football/premier-league/top-scorers" hreflang="en" rel="alternate"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-36.4462ac53e0.png" rel="icon" sizes="36x36" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-48.889764e1f5.png" rel="icon" sizes="48x48" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-57.d66bb4d3af.png" rel="icon" sizes="57x57" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-60.ea49e5ffb8.png" rel="icon" sizes="60x60" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-72.1e5fc819b5.png" rel="icon" sizes="72x72" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-76.34703514a6.png" rel="icon" sizes="76x76" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-96.a040328c4e.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-114.fe9c3f2019.png" rel="icon" sizes="114x114" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-120.8ed642b324.png" rel="icon" sizes="120x120" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-128.120915c059.png" rel="icon" sizes="128x128" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-144.15dd10e42c.png" rel="icon" sizes="144x144" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-152.fd46d402eb.png" rel="icon" sizes="152x152" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-180.f21cfb03df.png" rel="icon" sizes="180x180" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-192.79e4069625.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-384.ae211a8aa4.png" rel="icon" sizes="384x384" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/touch/sport/touch-icon-512.239d26b83e.png" rel="icon" sizes="512x512" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/sport/favicon-16.ffa949edba.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/sport/favicon-32.729e81a820.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link data-rh="true" href="https://static.files.bbci.co.uk/core/manifest.1ccdbcfd4cc3bf889128a50903c2b22c81758637.json" rel="manifest"/>
#   <script nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL">
#    document.querySelector("html").classList.remove("no-js")
#   </script>
#   <style data-emotion="ssrcss-global 1oz6top">
#    html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;}:root{interpolate-size:allow-keywords;}body{line-height:1;-webkit-text-size-adjust:none;-moz-text-size-adjust:none;-ms-text-size-adjust:none;text-size-adjust:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote::before,blockquote::after,q::before,q::after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}button{-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;margin:0;padding:0;background:none;border-radius:0;border:0;font-family:inherit;color:inherit;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff) format('woff');font-display:swap;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_It.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_It.woff) format('woff');font-display:swap;font-style:italic;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Bd.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Bd.woff) format('woff');font-display:swap;font-weight:700;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_BdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_BdIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:700;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Lt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Lt.woff) format('woff');font-display:swap;font-weight:300;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_LtIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_LtIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:300;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBd.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBd.woff) format('woff');font-display:swap;font-weight:800;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_ExBdIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:800;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Md.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Md.woff) format('woff');font-display:swap;font-weight:500;}@font-face{font-family:'ReithSans';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_MdIt.woff2) format('woff2'),url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_MdIt.woff) format('woff');font-display:swap;font-style:italic;font-weight:500;}@font-face{font-family:'ReithSerif';src:url(https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSer ...
#   </style>
#   <style data-emotion="ssrcss 181c4hk-SectionWrapper 1imfos9-PageStack 16kqp45-GlobalNavigation 1xvly21-Wrap j0nnoz-GlobalNavigationContent 1ho0ddd-GlobalNavigationItem yaim0e-NavigationLink-LogoLink 2fdbm9-IconWrapper-LogoIconWrapper i2z2ig-VisuallyHidden 49m975-AccessibilityLinksOffset 1aklli1-AccessibilityLink cx4hh2-GlobalNavigationItem 1ydzfwg-AccountOptionsList 1akot56-GlobalNavigationListItem-GlobalNavigationAccount 1igua52-
0-StyledLink 1sdg3ez-LinkTextContainer 1fbvkm-StyledLink 1ro2vxk-ToggleContainer dr47hj-MenuContainer-MoreMenuWrapper wdgq9j-MoreMenuListContainer j6f6xh-MenuListContainer 1mlqmic-ListTitle 1tflc9a-StyledMenuList 1cp5r2l-StyledMenuItem 1iyklul-StyledLink i9csl0-LinkTextContainer s6ioaa-MenuContainer-SecondaryNavBarContainer 1qa7b1l-MenuListContainer zu8opf-StyledMenuList 1k13if-StyledMenuItem 1lwb8hg-StyledLink 12rp8ws-LinkTextContainer p4fm83-IconContainer 1p1be2q-StyledLink t9s73x-StandardZone gqrsw0-Wrapper 1qdh4qq-HeadingWrapper 1sc9t00-Heading 59a716-SearchWrapper 1hy9pi-StyledComboboxWrapper 1sgucu0-StyledWrapper 2j3s5k-SearchBarWrapper 1ygb9tb-StyledDiv 15ptkq8-FocusDiv bynhw5-IconWrapper 11tm9xm-StyledInput 1ps7ft7-StyledFormWrapper e7zlj9-Button alld1g-Tabs 19cjfm5-TabListContainer f5gts8-TabList ii4qg7-TabListItem t4mrcq-TabLink 1jv6l5n-TabPanelContainer 198yp8f-TableWrapper 140ec4w-RelativeWrapper 1dv84pz-OuterTableWrapper 1pwsb40-TableWrapper 1jqazkt-TableHead 15w04vq-StyledTableHeading gkpmfa-StyledTab ...
#    .ssrcss-181c4hk-SectionWrapper{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100vh;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.ssrcss-1imfos9-PageStack{width:100%;height:100vh;display:grid;grid-template-rows:max-content auto max-content;grid-template-columns:100%;}.ssrcss-16kqp45-GlobalNavigation{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:700;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;background:#FFFFFF;color:#000000;box-shadow:0 0.0625rem 0 rgba(0,0,0,0.15);position:relative;z-index:1;--nav-item-display-0:none;--more-menu-item-display-0:initial;--nav-item-display-1:none;--more-menu-item-display-1:initial;--nav-item-display-2:none;--more-menu-item-display-2:initial;--nav-item-display-3:none;--more-menu-item-display-3:initial;--nav-item-display-4:none;--more-menu-item-display-4:initial;--nav-item-display-5:none;--more-menu-item-display-5:initial;--nav-item-display-6:none;--more-menu-item-display-6:initial;--nav-item-display-7:none;--more-menu-item-display-7:initial;--nav-item-display-8:none;--more-menu-item-display-8:initial;--nav-item-display-9:none;--more-menu-item-display-9:initial;--nav-item-display-10:none;--more-menu-item-display-10:initial;--nav-item-display-11:none;--more-menu-item-display-11:initial;--nav-item-display-12:none;--more-menu-item-display-12:initial;}@media (min-width: 37.5rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-0:initial;--more-menu-item-display-0:none;}}@media (min-width: 37.5rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-1:initial;--more-menu-item-display-1:none;}}@media (min-width: 37.5rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-2:initial;--more-menu-item-display-2:none;}}@media (min-width: 37.5rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-3:initial;--more-menu-item-display-3:none;}}@media (min-width: 39.84375rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-4:initial;--more-menu-item-display-4:none;}}@media (min-width: 43.3125rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-5:initial;--more-menu-item-display-5:none;}}@media (min-width: 47.296875rem){.ssrcss-16kqp45-GlobalNavigation{--nav-item-display-6:initial;--more-menu-item-display-6:none;}}.ssrcss-1xvly21-Wrap{box-sizing:border-box;margin:0 auto;max-width:63rem;padding:0 8px;}@media (min-width: 25rem){.ssrcss-1xvly21-Wrap{padding:0 16px;}}@media (min-width: 80rem){.ssrcss-1xvly21-Wrap{max-width:80rem;}}.ssrcss-j0nnoz-GlobalNavigationContent{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-evenly;-ms-flex-pack:space-evenly;-webkit-justify-content:space-evenly;justify-content:space-evenly;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:relative;padding:0.125rem 0;}.ssrcss-j0nnoz-GlobalNavigationContent >.eki2hvo23,.ssrcss-j0nnoz-GlobalNavigationContent .eki2hvo24{height:calc(3.375rem - 4px);padding:0.125rem 0;}@media (min-width: 18.75rem){.ssrcss-j0nnoz-GlobalNavigationContent >.eki2hvo23,.ssrcss-j0nnoz-GlobalNavigationContent .eki2hvo24{height:calc(4rem - 8px);}}@media (max-width: 18.74875rem){.ssrcss-j0nnoz-GlobalNavigationContent{width:100%;box-sizing:border-box;}.ssrcss-j0nnoz-GlobalNavigationContent >div:first-of-type{width:100%;}}@media (min-width: 18.75rem){.ssrcss-j0nnoz-GlobalNavigationContent{-webkit-box-flex-wrap:nowrap;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;}}.ssrcss-1ho0ddd-GlobalNavigationItem{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;}@media (min-width: 18.75rem){.ssrcss-1ho0ddd-GlobalNavigationItem{-webkit-order:1;-ms-flex-order:1;o ...
#       to right,
#       color(from #181818 srgb r g b / 0),
#       color(from #C8C8C8 srgb r g b / 0.8)
# );}.ssrcss-1pwsb40-TableWrapper{width:100%;}.ssrcss-1pwsb40-TableWrapper td:nth-child(){white-space:nowrap;}.ssrcss-1pwsb40-TableWrapper th:nth-child(),.ssrcss-1pwsb40-TableWrapper td:nth-child(){position:-webkit-sticky;position:sticky;left:0;z-index:1;}.no-js .ssrcss-1pwsb40-TableWrapper th:nth-child(),.no-js .ssrcss-1pwsb40-TableWrapper td:nth-child(){position:static;}.ssrcss-1pwsb40-TableWrapper.scrolled th:nth-child(){background-color:#F8F8F8;}.ssrcss-1pwsb40-TableWrapper.scrolled th:nth-child()::after{content:'';position:absolute;top:0;right:0;bottom:0;width:0.0625rem;background:#C8C8C8;}.ssrcss-1jqazkt-TableHead{background-color:#F8F8F8;border-bottom:none;}.ssrcss-15w04vq-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:left;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;vertical-align:middle;padding:12px 8px 8px;}@media (min-width: 37.5rem){.ssrcss-15w04vq-StyledTableHeading{font-size:0.875rem;line-height:1.2857142857142858;padding:12px 12px;}}.ssrcss-gkpmfa-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:right;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;vertical-align:middle;padding:12px 8px 8px;display:none;}@media (min-width: 37.5rem){.ssrcss-gkpmfa-StyledTableHeading{font-size:0.875rem;line-height:1.2857142857142858;padding:12px 12px;}}@media (min-width: 37.5rem){.ssrcss-gkpmfa-StyledTableHeading{display:table-cell;display:revert;}}.ssrcss-bcyg3t-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:right;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;vertical-align:middle;padding:12px 8px 8px;}@media (min-width: 37.5rem){.ssrcss-bcyg3t-StyledTableHeading{font-size:0.875rem;line-height:1.2857142857142858;padding:12px 12px;}}@media (min-width: 37.5rem){.ssrcss-bcyg3t-StyledTableHeading{display:none;}}.ssrcss-1rqm9ar-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:right;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;vertical-align:middle;padding:12px 8px 8px;display:none;}@media (min-width: 37.5rem){.ssrcss-1rqm9ar-StyledTableHeading{font-size:0.875rem;line-height:1.2857142857142858;padding:12px 12px;}}@media (min-width: 56.25rem){.ssrcss-1rqm9ar-StyledTableHeading{display:table-cell;display:revert;}}.ssrcss-4k41u5-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:right;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;vertical-align:middle;padding:12px 8px 8px;}@media (min-width: 37.5rem){.ssrcss-4k41u5-StyledTableHeading{font-size:0.875rem;line-height:1.2857142857142858;padding:12px 12px;}}@media (min-width: 56.25rem){.ssrcss-4k41u5-StyledTableHeading{display:none;}}.ssrcss-a52s4k-StyledTableHeading{font-family:ReithSans,Helvetica,Arial,freesans,sans-serif;font-weight:400;font-feature-settings:'ss01' off;font-size:0.8125rem;line-height:1.2307692307692308;color:#181818;text-align:right;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;vertical-align:middle;padding:12px 8px 8px;display:none;}@media (min-width: 37.5rem){.ssrcss-a52s4k-StyledTableHeading{font-size:0.875rem;l ...
#   </style>
#  </head>
#  <body>
#   <div id="root">
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/manchester-city.e4f9593ae9.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/brentford.aa0256ca6b.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/chelsea.59e0e1ec22.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/brighton-and-hove-albion.4522a78440.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/arsenal.5be7ff54ce.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/liverpool.34999937ef.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/leeds-united.9f3e6b50e8.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/fulham.18d9a9610c.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/afc-bournemouth.3e0ae7da8e.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/crystal-palace.0130d519e0.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/newcastle-united.7daf913814.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/tottenham-hotspur.f1c704ee3b.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/manchester-united.80807495b5.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/nottingham-forest.f0fc0fc962.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/aston-villa.7462c0d498.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/west-ham-united.94ab875a64.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/burnley.03819b9eba.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/everton.38c006ac78.svg" rel="preload"/>
#    <link as="image" href="https://static.files.bbci.co.uk/core/website/assets/static/sport/football/sunderland.6f27d0f277.svg" rel="preload"/>
#    <div class="ssrcss-181c4hk-SectionWrapper eustbbg0">
#     <div class="ssrcss-1imfos9-PageStack e1k195vp1">
#      <div>
#       <div>
#        <header data-testid="header-content" id="header-content">
#         <nav aria-label="BBC" class="ssrcss-16kqp45-GlobalNavigation e4np8gz0">
#          <div class="ssrcss-1xvly21-Wrap e42f8511">
#           <div class="ssrcss-j0nnoz-GlobalNavigationContent eki2hvo22" id="global-navigation">
#            <div class="ssrcss-1ho0ddd-GlobalNavigationItem eki2hvo23">
#             <a class="ssrcss-yaim0e-NavigationLink-LogoLink eki2hvo11" href="https://www.bbc.com">
#              <span class="ssrcss-2fdbm9-IconWrapper-LogoIconWrapper eki2hvo6">
#               <svg fill="currentColor" height="2em" viewbox="0 0 112 32" width="7em" xmlns="http://www.w3.org/2000/svg">
#                <path d="M111.99999,4.44444577e-05 L111.99999,32.0000444 L79.9999905,32.0000444 L79.9999905,4.44444577e-05 L111.99999,4.44444577e-05 Z M72.0000119,-3.55271368e-15 L72.0000119,32 L40.0000119,32 L40.0000119,-3.55271368e-15 L72.0000119,-3.55271368e-15 Z M32,-3.55271368e-15 L32,32 L-1.13686838e-13,32 L-1.13686838e-13,-3.55271368e-15 L32,-3.55271368e-15 Z M97.469329,6.80826869 C96.0294397,6.80826869 94.7294393,7.02226876 93.5693278,7.44982444 C92.4089942,7.87782457 91.4137717,8.49471364 90.5841047,9.30049166 C89.7538823,10.1067141 89.1188821,11.07327 88.6785486,12.199937 C88.2378818,13.3269373 88.0177706,14.5896043 88.0177706,15.9876048 C88.0177706,17.4188274 88.2296596,18.7062722 88.6531042,19.8493837 C89.0763265,20.9929396 89.6861045,21.9591621 90.482438,22.748829 C91.2784383,23.5383848 92.2522163,24.1430516 93.4042167,24.5624962 C94.5558837,24.9819408 95.8516619,25.1917186 97.2914401,25.1917186 C98.3752182,25.1917186 99.4086629,25.072163 100.391219,24.8338296 C101.37333,24.5956073 102.237108
#                </path>
#               </svg>
#               <span class="visually-hidden ssrcss-i2z2ig-VisuallyHidden e16en2lz0">
#                BBC Homepage
#               </span>
#              </span>
#             </a>
#            </div>
#            <div class="ssrcss-49m975-AccessibilityLinksOffset eki2hvo0">
#             <ul id="accessibility-links" role="list">
#              <li>
#               <a class="ssrcss-1aklli1-AccessibilityLink e14hijrs0" href="#main-heading">
#                Skip to content
#               </a>
#              </li>
#              <li>
#               <a class="ssrcss-1aklli1-AccessibilityLink e14hijrs0" href="https://www.bbc.co.uk/accessibility/">
#                Accessibility Help
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="ssrcss-cx4hh2-GlobalNavigationItem eki2hvo23">
#             <ul class="ssrcss-1ydzfwg-AccountOptionsList eki2hvo1" role="list">
#              <li class="ssrcss-1akot56-GlobalNavigationListItem-GlobalNavigationAccount eki2hvo15">
#               <span class="ssrcss-1igua52-AccountComponentWrapper eki2hvo9">
#                <div class="ssrcss-uwr32o-StyledAccountPlaceholderComponent elvs26v5" id="account-placeholder">
#                 <div class="ssrcss-n7m3zs-StyledLoadingPlaceholderWrapper elvs26v0">
#                  <span class="ssrcss-9fdrh7-StyledAccountPlaceholderIconWrapper elvs26v4">
#                   <div class="elvs26v3 ssrcss-pi49ph-Skeleton-StyledAccountPlaceholderIcon en1pbmi0" data-testid="skeleton-wrapper">
#                   </div>
#                  </span>
#                  <span class="ssrcss-h42kmd-StyledLoadingPlaceHolderTextWrapper elvs26v2">
#                   <div class="elvs26v1 ssrcss-31p6q0-Skeleton-StyledLoadingPlaceHolderText en1pbmi0" data-testid="skeleton-wrapper">
#                   </div>
#                  </span>
#                 </div>
#                </div>
#                <a aria-hidden="true" class="ssrcss-7xnt2x-NavigationLink-AccountLink eki2hvo10" hidden="" href="https://account.bbc.com/account?lang=en-GB&amp;ptrt=https%3A%2F%2Fwww.bbc.com%2Fsport%2Ffootball%2Fpremier-league%2Ftop-scorers&amp;userOrigin=SPORT_GNL">
#                 <div class="ssrcss-1e5u46l-AccountWrapper e1jj8uav4">
#                  <span class="ssrcss-18rlmxu-IconWrapper-ForYouIconWrapper e1jj8uav2">
#                   <svg aria-hidden="true" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" height="1em" viewbox="0 0 32 32" width="1em">
#                    <path d="M16 23c-3.3 0-5.8-2.5-5.8-5.8s2.5-5.8 5.8-5.8c3.2 0 5.8 2.5 5.8 5.8S19.2 23 16 23m15-5.7c0-8.4-6.6-15-15-15-8.5 0-15 6.6-15 15 0 5.2 2.5 9.8 6.4 12.4 1.9-2.8 5-4.6 8.6-4.6s6.7 1.8 8.6 4.6C28.5 27 31 22.5 31 17.3">
#                    </path>
#                   </svg>
#                  </span>
#                  <span class="ssrcss-1vpd218-AccountText e1jj8uav1">
#                   Your account
#                  </span>
#                 </div>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <div class="ssrcss-wq45sa-VerticalSeparator eki2hvo8">
#             </div>
#             <ul class="ssrcss-be8c0u-GlobalNavigationBarLinkList eki2hvo21" role="list">
#              <li class="ssrcss-iqkw4o-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com">
#                Home
#               </a>
#              </li>
#              <li class="ssrcss-1ayvst8-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/news">
#                News
#               </a>
#              </li>
#              <li class="ssrcss-lgxq8r-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/sport">
#                Sport
#               </a>
#              </li>
#              <li class="ssrcss-cuez20-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/business">
#                Business
#               </a>
#              </li>
#              <li class="ssrcss-bka0uc-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/technology">
#                Technology
#               </a>
#              </li>
#              <li class="ssrcss-10vlqny-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/health">
#                Health
#               </a>
#              </li>
#              <li class="ssrcss-1e5i6ba-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/culture">
#                Culture
#               </a>
#              </li>
#              <li class="ssrcss-w3zqa5-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/arts">
#                Arts
#               </a>
#              </li>
#              <li class="ssrcss-54olj4-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/travel">
#                Travel
#               </a>
#              </li>
#              <li class="ssrcss-pzyl57-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/future-planet">
#                Earth
#               </a>
#              </li>
#              <li class="ssrcss-16e4dqn-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/audio">
#                Audio
#               </a>
#              </li>
#              <li class="ssrcss-pi0i14-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/video">
#                Video
#               </a>
#              </li>
#              <li class="ssrcss-o8afqa-GlobalNavigationListItem-GlobalNavigationProduct eki2hvo19">
#               <a class="ssrcss-19tcxpt-NavigationLink eki2hvo14" href="https://www.bbc.com/live">
#                Live
#               </a>
#              </li>
#             </ul>
#             <div class="ssrcss-15v1ilo-GlobalNavigationMoreButton-GlobalNavigationListItem-GlobalNavigationMoreButton eki2hvo18" id="more-menu-button">
#              <a class="ssrcss-smku24-NavigationLink eki2hvo14" href="#global-navigation-more-menu">
#               <span class="ssrcss-1q15g6h-IconWrapper-DotsMenuIconWrapper eki2hvo2">
#                <svg fill="currentColor" height="0.25em" viewbox="0 0 20 4" width="1.25em" xmlns="http://www.w3.org/2000/svg">
#                 <g transform="translate(-14.000000, -22.000000)">
#                  <path d="M18,22 L18,26 L14,26 L14,22 L18,22 Z M34,22 L34,26 L30,26 L30,22 L34,22 Z M26,22 L26,26 L22,26 L22,22 L26,22 Z">
#                  </path>
#                 </g>
#                </svg>
#                <span class="visually-hidden ssrcss-i2z2ig-VisuallyHidden e16en2lz0">
#                 More menu
#                </span>
#               </span>
#              </a>
#             </div>
#            </div>
#            <div class="ssrcss-1naw1ix-LastGlobalNavigationItem eki2hvo24">
#             <div class="ssrcss-e93oh-GlobalNavigationItem-GlobalNavigationBurger eki2hvo16">
#              <a class="ssrcss-smku24-NavigationLink eki2hvo14" href="#global-navigation-more-menu">
#               <span class="ssrcss-1qnhcor-IconWrapper-BurgerMenuIconWrapper eki2hvo3">
#                <svg fill="currentColor" height="1.375em" version="1.1" viewbox="0 0 24 22" width="1.5em" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M24,18 L24,22 L0,22 L0,18 L24,18 Z M24,9 L24,13 L0,13 L0,9 L24,9 Z M24,0 L24,4 L0,4 L0,0 L24,0 Z">
#                 </path>
#                </svg>
#                <span class="visually-hidden ssrcss-i2z2ig-VisuallyHidden e16en2lz0">
#                 More menu
#                </span>
#               </span>
#              </a>
#             </div>
#             <div aria-label="Search BBC" class="ssrcss-1g62j0z-GlobalNavigationItem-GlobalNavigationSearch eki2hvo17" role="search">
#              <a class="ssrcss-18f0rm9-NavigationLink-SearchLink eki2hvo13" href="https://www.bbc.com/search?d=SPORT_GNL">
#               <span class="ssrcss-1quqv85-IconWrapper-SearchIconWrapper eki2hvo4">
#                <svg aria-hidden="true" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" height="1em" viewbox="0 0 32 32" width="1em">
#                 <path d="m30.6 28.1-8.3-8.3c1.5-2 2.4-4.4 2.4-7.2C24.7 6 19.6 1 13 1S1.4 6.1 1.4 12.7 6.5 24.3 13 24.3c2.3 0 4.4-.6 6.2-1.8l8.5 8.5zM4 12.6c0-5.2 3.9-9.1 9-9.1s9 3.9 9 9.1-3.9 9.1-9 9.1-9-3.9-9-9.1">
#                 </path>
#                </svg>
#               </span>
#               <span class="ssrcss-v56yg5-SearchText eki2hvo12">
#                Search BBC
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="ssrcss-hi2bgt-GlobalNavigationDrawer e6xn3ao0" tabindex="-1">
#           <div class="ssrcss-zsw9p8-GlobalNavigationMoreMenu e2z809s5" id="global-navigation-more-menu" rows="7">
#            <div class="ssrcss-1xvly21-Wrap e42f8511">
#             <div class="ssrcss-1obp207-MenuWrapper e2z809s1">
#              <ul class="ssrcss-17l23qb-MenuLinkList e2z809s4" role="list" tabindex="-1">
#               <li class="ssrcss-z50uku-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com">
#                 Home
#                </a>
#               </li>
#               <li class="ssrcss-dwmhfn-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/news">
#                 News
#                </a>
#               </li>
#               <li class="ssrcss-zwtpfj-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/sport">
#                 Sport
#                </a>
#               </li>
#               <li class="ssrcss-1ruazab-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/business">
#                 Business
#                </a>
#               </li>
#               <li class="ssrcss-i8nx6n-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/technology">
#                 Technology
#                </a>
#               </li>
#               <li class="ssrcss-1tsa4lb-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/health">
#                 Health
#                </a>
#               </li>
#               <li class="ssrcss-165ongx-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/culture">
#                 Culture
#                </a>
#               </li>
#               <li class="ssrcss-xtzp6k-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/arts">
#                 Arts
#                </a>
#               </li>
#               <li class="ssrcss-yra2hv-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/travel">
#                 Travel
#                </a>
#               </li>
#               <li class="ssrcss-1ygpztk-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/future-planet">
#                 Earth
#                </a>
#               </li>
#               <li class="ssrcss-1vag0s7-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/audio">
#                 Audio
#                </a>
#               </li>
#               <li class="ssrcss-1x379b1-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/video">
#                 Video
#                </a>
#               </li>
#               <li class="ssrcss-1yxh7ao-MenuLinkListItem e2z809s3">
#                <a class="ssrcss-kffy1u-MenuLink e2z809s2" href="https://www.bbc.com/live">
#                 Live
#                </a>
#               </li>
#              </ul>
#              <div class="ssrcss-h8eoet-CloseButtonWrapper e2z809s0">
#               <a class="ssrcss-3n7ku2-CallToActionLink esxl4sy1" href="#more-menu-button">
#                <span class="ssrcss-1hfawy1-IconWrapper esxl4sy0" data-testid="actions:close">
#                 <svg aria-hidden="true" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" height="1em" viewbox="0 0 32 32" width="1em">
#                  <path d="m30 4.6-2.8-2.8L2 27.4l2.8 2.8zM4.8 1.8 1.9 4.7l25.2 25.5 2.9-2.9z">
#                  </path>
#                 </svg>
#                 <span class="visually-hidden ssrcss-i2z2ig-VisuallyHidden e16en2lz0">
#                  <span class="call-to-action-link-text-wrapper">
#                   Close menu
#                  </span>
#                 </span>
#                </span>
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </nav>
#         <div class="ssrcss-1goh7cj-ProductNavigationContainer e19b3odl1">
#          <div class="ssrcss-hgsun2-Masthead esbu9dd2" data-testid="masthead">
#           <div class="ssrcss-1xvly21-Wrap e42f8511">
#            <div class="ssrcss-b8qhq3-ContentWrapper esbu9dd0">
#             <div class="ssrcss-1nqrevo-LogoWrapper esbu9dd5">
#              <a class="ssrcss-1vyfvn-LogoLink esbu9dd4" href="/sport">
#               <svg aria-hidden="true" class="ssrcss-1xljs8d-LogoIcon esbu9dd7" focusable="false" preserveaspectratio="xMinYMid meet" role="presentation" viewbox="0 0 762 170" xmlns="http://www.w3.org/2000/svg">

#                  <svg aria-hidden="true" class="ssrcss-xi5oyi-StyledIcon e161cein1" focusable="false" height="1em" viewbox="0 0 32 32" width="1em">
#                   <path d="M1 7.5h30V1.9H1zm0 22.6h30v-5.6H1zm0-11.3h30v-5.6H1z">
#                   </path>
#                  </svg>
#                 </span>
#                 Menu
#                </a>
#               </div>
#               <div class="ssrcss-hlliht-MenuListContainer e14xdrat2" hidden="">
#                <ul class="ssrcss-pe8g9s-StyledMenuList e14xdrat1" role="list">
#                 <li class="ssrcss-42zvi3-StyledMenuItem eis6szr3">
#                  <a class="ssrcss-yt6oi0-StyledLink eis6szr2" href="/sport">
#                   <span class="ssrcss-1sdg3ez-LinkTextContainer eis6szr1">
#                    Home
#                   </span>
#                  </a>
#                 </li>
#                 <li aria-current="true" class="ssrcss-42zvi3-StyledMenuItem eis6szr3">
#                  <a class="ssrcss-1fbvkm-StyledLink eis6szr2" href="/sport/football">
#                   <span class="ssrcss-1sdg3ez-LinkTextContainer eis6szr1">
#                    Football
#                   </span>
#                  </a>
#                 </li>
#                 <li class="ssrcss-42zvi3-StyledMenuItem eis6szr3">
#                  <a class="ssrcss-yt6oi0-StyledLink eis6szr2" href="/sport/cricket">
#                   <span class="ssrcss-1sdg3ez-LinkTextContainer eis6szr1">
#                    Cricket
#                   </span>
#                  </a>
#                 </li>
#                 <li class="ssrcss-42zvi3-StyledMenuItem eis6szr3">
# ...
#               Technology
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/health">
#               Health
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/culture">
#               Culture
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/arts">
#               Arts
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/travel">
#               Travel
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/future-planet">
#               Earth
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/audio">
#               Audio
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/video">
#               Video
#              </a>
#             </li>
#             <li>
#              <a class="ssrcss-eadmwc-Link-NavigationLink e130hpyp0" href="https://www.bbc.com/live">
#               Live
#              </a>
#             </li>
#            </ul>
#            <div class="ssrcss-15twdc6-Stack e1y4nx260" spacing="6">
#             <div class="ssrcss-17ehax8-Cluster e1ihwmse1">
#              <ul class="ssrcss-rf8ukd-ClusterItems e1ihwmse0" role="list" spacing="6">
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.com/pages/terms-of-use">
#                 Terms of Use
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.co.uk/aboutthebbc">
#                 About the BBC
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.com/pages/privacy-policy">
#                 Privacy Policy
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.com/usingthebbc/cookies">
#                 Cookies
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.co.uk/accessibility">
#                 Accessibility Help
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.co.uk/iplayer/guidance">
#                 Parental Guidance
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.co.uk/contact">
#                 Contact the BBC
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.co.uk/bbcnewsletter">
#                 BBC emails for you
#                </a>
#               </li>
#               <li>
#                <a class="ssrcss-qj1vys-Link-LegalLink e1nhpvv71" href="https://www.bbc.com/advertisingcontact/">
#                 Advertise with us
#                </a>
#               </li>
#              </ul>
#             </div>
#             <p class="ssrcss-1q0x1qg-Paragraph e1jhz7w10">
#              Copyright © 2026 BBC. The BBC is not responsible for the content of external sites.
#              <a class="ssrcss-8iic47-Link e14mg4ud0" href="https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-links">
#               Read about our approach to external linking.
#              </a>
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </footer>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL">
#    window.__WEBAPP_CONFIG__="{\"staticBaseUrl\":\"https://static.files.bbci.co.uk/core\",\"apiUrl\":\"/wc-data\",\"pollingApiUrl\":\"/wc-poll-data\",\"hostUrl\":\"https://www.bbc.co.uk\",\"cdnHostUrl\":\"https://web-cdn.api.bbci.co.uk\",\"reportingEndpoint\":\"https://webcore.bbc-reporting-api.app/report-endpoint\",\"webVitalsSampleRate\":20,\"manifestName\":\"manifest.1ccdbcfd4cc3bf889128a50903c2b22c81758637.json\"}";
#   </script>
#   <script nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL">
#    window.__INITIAL_DATA__="{\"data\":{\"global-navigation?country=de&language=en-GB&service=commercial\":{\"name\":\"global-navigation\",\"props\":{\"country\":\"de\",\"language\":\"en-GB\",\"service\":\"commercial\"},\"data\":{\"accessibilityLinks\":[{\"label\":\"Skip to content\",\"url\":\"#main-heading\"},{\"label\":\"Accessibility Help\",\"url\":\"https://www.bbc.co.uk/accessibility/\"}],\"signInLabel\":\"Sign in\",\"accountLabel\":\"Your account\",\"forYouLabel\":\"For you\",\"forYouUrl\":\"https://www.bbc.co.uk/foryou\",\"menuLabel\":\"Menu\",\"moreLabel\":\"More\",\"moreMenuLabel\":\"More menu\",\"closeButtonLabel\":\"Close menu\",\"disclaimer\":{\"text\":\"Copyright © 2026 BBC. The BBC is not responsible for the content of external sites.\",\"link\":{\"url\":\"https://www.bbc.co.uk/editorialguidelines/guidance/feeds-and-
false},{\"label\":\"Football\",\"url\":\"/sport/football\",\"selected\":true,\"hidden\":false},{\"label\":\"Cricket\",\"url\":\"/sport/cricket\",\"selected\":false,\"hidden\":false},{\"label\":\"Formula 1\",\"url\":\"/sport/formula1\",\"selected\":false,\"hidden\":false},{\"label\":\"Rugby U\",\"url\":\"/sport/rugby-union\",\"selected\":false,\"hidden\":false},{\"label\":\"Tennis\",\"url\":\"/sport/tennis\",\"selected\":false,\"hidden\":false},{\"label\":\"Golf\",\"url\":\"/sport/golf\",\"selected\":false,\"hidd ...
#   </script>
#   <script nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL">
#    window.__REQUEST_CONTEXT__="{\"queryStringParameters\":{},\"headers\":{\"user-agent\":\"Belfrage\",\"signedin\":\"no\",\"language\":\"en-GB\",\"is_uk\":false,\"is_commercial\":\"true\",\"ctx-route-spec\":\"SportDataFootballTopScorersWebcore.Webcore\",\"ctx-dark-mode-preference\":\"on\",\"country\":\"de\",\"belfrage-time\":\"2026-04-18T23:47:18.582393Z\",\"bbc-host\":\"www.bbc.com\",\"accept-encoding\":\"gzip\",\"host\":\"www.bbc.com\",\"env\":\"live\",\"nonce\":\"vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL\"},\"isAppRoute\":false}";
#   </script>
#   <script nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL">
#    window.__ENVIRONMENT_VARIABLES__="{\"disableChartbeat\":false,\"reportingEndpoint\":\"https://webcore.bbc-reporting-api.app/report-endpoint\",\"webVitalsSampleRate\":20}";
#   </script>
#   <script crossorigin="anonymous" id="__LOADABLE_REQUIRED_CHUNKS__" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" type="application/json">
#    [774,8332,5077,7897,7167,7053,8926,4140,8549,6593,6612,9693,4636,7119,9423,8309,2854,3744,9754,5866]
#   </script>
#   <script crossorigin="anonymous" id="__LOADABLE_REQUIRED_CHUNKS___ext" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" type="application/json">
#    {"namedChunks":["website-containers-global-navigation-index-js","design-system-svgs-account-index-jsx","design-system-svgs-actions-index-jsx","website-containers-product-navigation-index-js","design-system-svgs-logo-index-jsx","design-system-svgs-arrows-index-jsx","website-containers-football-top-scorers-index-js","website-containers-global-footer-index-js","website-addons-document-metadata-index-jsx","website-addons-cookies-module-index-jsx"]}
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-vendor-optimizely.59247a9d8bfc766bfe78.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-default-vendors.daaeb91fc3775b616777.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-tabs.556672f6cfd12fc0514d.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-gel.30dcaec82653eeba0c78.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-website.3738686ad2ef160de491.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-base-website.ef1ff867ec48e1de3a37.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-framework.62d9d18c4522fb7c731c.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="pwa" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-pwa.9e1d2e3f1c03b5b8d9fc.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-global-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-button.bcddf040efea4ddf88f7.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-global-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-call-to-action-link.dfbbea8fab48b7b33ded.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-global-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-global-navigation.ae3d56b88c0b87079b99.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-global-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-global-navigation.9a721964c87f91c8f799.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-product-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-image.3dc0bda75e1a9fc7f3dc.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-product-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-product-navigation.4231410916876aab7d15.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-product-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-masthead.aceb6c59b7f46b0c5811.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-product-navigation-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-product-navigation.f477a218b62f9ed3ad34.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-football-top-scorers-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-sport-badge.9ef9e3a997f2187d7020.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-football-top-scorers-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-sport-table.c4f5f21dcf1102aabd62.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-football-top-scorers-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-component-combobox.a206484612ef70dbce28.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-football-top-scorers-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-football-top-scorers.9deb94be47a36fecb879.js" type="module">
#   </script>
#   <script async="" crossorigin="anonymous" data-chunk="website-containers-global-footer-index-js" nonce="vTv5ov1vDrLYZeHs57+xaihOVIA+4m9TY98OHuhzeRG1NTIfjL" src="https://static.files.bbci.co.uk/core/bundle-global-footer.4efbf4256e389248d43b.js" type="module">
#   </script>
#  </body>
# </html>
